# %% [markdown]
# # ReThink Twitter API User Template
# ---
# This notebook provides a simple, stripped-down version of the user guide that can be easily adjusted and run for different topics. For more in-depth definitions, explanations, and examples for each function, please refer to [the user guide](https://github.com/lana-e/rethink-twitter/blob/main/notebooks/ReThink%20Twitter%20API%20User%20Guide.ipynb).
#
# This template was created for the user to define everything they need in the first cell, and then run the rest of the notebook with minimal adjustment needed. Arguments can be adjusted and additional function calls can be made as needed, but a user can get meaningful analysis from this pipeline directly out of the box.

# %%
# importing functions from rethink_twitter_functions.py
from rethink_twitter_functions import *

# defining some search strings for the API queries
query1 = 'omicron'
query1_label = "Omicron Variant"
query1_start = "12/1/2021"
query1_end = "12/9/2021"

# %% [markdown]
# ## 7-day search

# %%
query1_7 = search_7(query1, max_results=100, write_csv=False)
query1_7.head()
# Out:
#                                                                   text  \
# Tweet ID
# 1469039051466371072  RT @Tuliodna: The #omicron has been detected i...
# 1469039049742733312  RT @sailorrooscout: World Health Organization:...
# 1469039042243219466  RT @sarahzhang: I'm sorry to say I'm worried a...
# 1469039039294681097  RT @EssexPR: Now Omicron is being billed as a ...
# 1469039037713465352  RT @RespiratoryDafe: Pfizer says booster appea...
#
#                     attachments            author_id  \
# Tweet ID
# 1469039051466371072        None            260603193
# 1469039049742733312        None           4461945688
# 1469039042243219466        None             17409753
# 1469039039294681097        None           3066352979
# 1469039037713465352        None  1154218146435350535
#
#                                                    context_annotations  \
# Tweet ID
# 1469039051466371072  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1469039049742733312                                               None
# 1469039042243219466  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1469039039294681097  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1469039037713465352  [{'domain': {'id': '123', 'name': 'Ongoing New...
#
#                          conversation_id                created_at  \
# Tweet ID
# 1469039051466371072  1469039051466371072 2021-12-09 20:19:37+00:00
# 1469039049742733312  1469039049742733312 2021-12-09 20:19:37+00:00
# 1469039042243219466  1469039042243219466 2021-12-09 20:19:35+00:00
# 1469039039294681097  1469039039294681097 2021-12-09 20:19:35+00:00
# 1469039037713465352  1469039037713465352 2021-12-09 20:19:34+00:00
#
#                                                               entities   geo  \
# Tweet ID
# 1469039051466371072  {'mentions': [{'start': 3, 'end': 12, 'usernam...  None
# 1469039049742733312  {'mentions': [{'start': 3, 'end': 18, 'usernam...  None
# 1469039042243219466  {'mentions': [{'start': 3, 'end': 14, 'usernam...  None
# 1469039039294681097  {'mentions': [{'start': 3, 'end': 11, 'usernam...  None
# 1469039037713465352  {'mentions': [{'start': 3, 'end': 19, 'usernam...  None
#
#                     in_reply_to_user_id lang referenced_tweets  \
# Tweet ID
# 1469039051466371072                None   en      [(type, id)]
# 1469039049742733312                None   en      [(type, id)]
# 1469039042243219466                None   en      [(type, id)]
# 1469039039294681097                None   en      [(type, id)]
# 1469039037713465352                None   en      [(type, id)]
#
#                     followers_count verified entities_hashtags retweet_count  \
# Tweet ID
# 1469039051466371072             876    False         [omicron]           397
# 1469039049742733312             634    False              None           666
# 1469039042243219466             236    False              None           179
# 1469039039294681097            2481    False              None            29
# 1469039037713465352            1135    False              None             5
#
#                     reply_count like_count quote_count total_engagements
# Tweet ID
# 1469039051466371072           0          0           0               397
# 1469039049742733312           0          0           0               666
# 1469039042243219466           0          0           0               179
# 1469039039294681097           0          0           0                29
# 1469039037713465352           0          0           0                 5

# %% [markdown]
# ## 30-day search

# %%
query1_30 = search_30(query1, max_results=100, write_csv=False)
query1_30.head()
# Out:
#                                                                   text  \
# Tweet ID
# 1469039473317093379  @hughhewitt @TimesofIsrael Omicron has been st...
# 1469039472830468103  RT @gamilnaseer4: the mass lockout in the worl...
# 1469039468103483396  RT @SkyNews: Dr Zubaida Haque, member of Indep...
# 1469039467134652421  RT @njoyflyfishing: Daily US Covid Deaths by C...
# 1469039466664787968  @RudkinRichard @andy_park @p_hannam Refusing j...
#
#                                                    attachments  \
# Tweet ID
# 1469039473317093379  {'media_keys': ['3_1469038730317025288']}
# 1469039472830468103                                       None
# 1469039468103483396                                       None
# 1469039467134652421                                       None
# 1469039466664787968                                       None
#
#                                author_id  \
# Tweet ID
# 1469039473317093379   783682433052971009
# 1469039472830468103  1457341130635452418
# 1469039468103483396           3437143726
# 1469039467134652421   983658091874054144
# 1469039466664787968           1099241996
#
#                                                    context_annotations  \
# Tweet ID
# 1469039473317093379  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1469039472830468103  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1469039468103483396  [{'domain': {'id': '47', 'name': 'Brand', 'des...
# 1469039467134652421  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1469039466664787968  [{'domain': {'id': '123', 'name': 'Ongoing New...
#
#                          conversation_id                created_at  \
# Tweet ID
# 1469039473317093379  1468887085079801859 2021-12-09 20:21:18+00:00
# 1469039472830468103  1469039472830468103 2021-12-09 20:21:18+00:00
# 1469039468103483396  1469039468103483396 2021-12-09 20:21:17+00:00
# 1469039467134652421  1469039467134652421 2021-12-09 20:21:17+00:00
# 1469039466664787968  1469022282399903744 2021-12-09 20:21:16+00:00
#
#                                                               entities   geo  \
# Tweet ID
# 1469039473317093379  {'urls': [{'start': 148, 'end': 171, 'url': 'h...  None
# 1469039472830468103  {'annotations': [{'start': 55, 'end': 60, 'pro...  None
# 1469039468103483396  {'annotations': [{'start': 13, 'end': 28, 'pro...  None
# 1469039467134652421  {'mentions': [{'start': 3, 'end': 18, 'usernam...  None
# 1469039466664787968  {'mentions': [{'start': 0, 'end': 14, 'usernam...  None
#
#                     in_reply_to_user_id lang referenced_tweets  \
# Tweet ID
# 1469039473317093379            15075999   en      [(type, id)]
# 1469039472830468103                None   en      [(type, id)]
# 1469039468103483396                None   en      [(type, id)]
# 1469039467134652421                None   en      [(type, id)]
# 1469039466664787968           490485171   en      [(type, id)]
#
#                     followers_count verified entities_hashtags retweet_count  \
# Tweet ID
# 1469039473317093379             112    False              None             0
# 1469039472830468103             108    False              None             1
# 1469039468103483396             293    False              None           114
# 1469039467134652421            1956    False              None             1
# 1469039466664787968             195    False              None             0
#
#                     reply_count like_count quote_count total_engagements
# Tweet ID
# 1469039473317093379           0          0           0                 0
# 1469039472830468103           0          0           0                 1
# 1469039468103483396           0          0           0               114
# 1469039467134652421           0          0           0                 1
# 1469039466664787968           0          0           0                 0

# %% [markdown]
# ## Full archive search

# %%
query1_full = search_full(query1, start_date=query1_start, end_date=query1_end, max_results=100, write_csv=False)
query1_full.head()
# Out:
#                                                                   text  \
# Tweet ID
# 1468732120814206984  RT @AP: #TheAPInterview: CDC chief Dr. Rochell...
# 1468732116737343490  RT @LCWF_TBK: Nothing in schools again, no vac...
# 1468732116263481352  RT @WTFJHT: The early data, which has not been...
# 1468732115529474057  RT @RMConservative: Bourla sounds mentally ill...
# 1468732113591541761  RT @ProfPCDoherty: This is good news. Early in...
#
#                     attachments            author_id  \
# Tweet ID
# 1468732120814206984        None            231156352
# 1468732116737343490        None            451664332
# 1468732116263481352        None             32088857
# 1468732115529474057        None  1239593072201207808
# 1468732113591541761        None             50534512
#
#                                                    context_annotations  \
# Tweet ID
# 1468732120814206984  [{'domain': {'id': '47', 'name': 'Brand', 'des...
# 1468732116737343490  [{'domain': {'id': '66', 'name': 'Interests an...
# 1468732116263481352  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1468732115529474057                                               None
# 1468732113591541761  [{'domain': {'id': '123', 'name': 'Ongoing New...
#
#                          conversation_id                created_at  \
# Tweet ID
# 1468732120814206984  1468732120814206984 2021-12-08 23:59:59+00:00
# 1468732116737343490  1468732116737343490 2021-12-08 23:59:59+00:00
# 1468732116263481352  1468732116263481352 2021-12-08 23:59:58+00:00
# 1468732115529474057  1468732115529474057 2021-12-08 23:59:58+00:00
# 1468732113591541761  1468732113591541761 2021-12-08 23:59:58+00:00
#
#                                                               entities   geo  \
# Tweet ID
# 1468732120814206984  {'hashtags': [{'start': 8, 'end': 23, 'tag': '...  None
# 1468732116737343490  {'mentions': [{'start': 3, 'end': 12, 'usernam...  None
# 1468732116263481352  {'mentions': [{'start': 3, 'end': 10, 'usernam...  None
# 1468732115529474057  {'annotations': [{'start': 20, 'end': 25, 'pro...  None
# 1468732113591541761  {'mentions': [{'start': 3, 'end': 17, 'usernam...  None
#
#                     in_reply_to_user_id lang referenced_tweets  \
# Tweet ID
# 1468732120814206984                None   en      [(type, id)]
# 1468732116737343490                None   en      [(type, id)]
# 1468732116263481352                None   en      [(type, id)]
# 1468732115529474057                None   en      [(type, id)]
# 1468732113591541761                None   en      [(type, id)]
#
#                     followers_count verified entities_hashtags retweet_count  \
# Tweet ID
# 1468732120814206984             944    False  [TheAPInterview]            28
# 1468732116737343490              76    False              None            20
# 1468732116263481352             245    False              None             1
# 1468732115529474057            2031    False              None            28
# 1468732113591541761             786    False              None           160
#
#                     reply_count like_count quote_count total_engagements
# Tweet ID
# 1468732120814206984           0          0           0                28
# 1468732116737343490           0          0           0                20
# 1468732116263481352           0          0           0                 1
# 1468732115529474057           0          0           0                28
# 1468732113591541761           0          0           0               160

# %% [markdown]
# ## Wordclouds

# %%
wordcloud, hashtags = word_cloud(query1_full, query=query1, save_imgs=False)
# Out:
# [nltk_data] Downloading package punkt to /home/lana-e/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Attention over time

# %%
plot = attention_plots(query1_full, query_labels=[query1_label], xlabel="day", plot_type="bar")
